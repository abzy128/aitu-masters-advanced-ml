# %% [markdown]
# # CatBoost Regression Model
#
# This notebook trains and evaluates a CatBoost Regression model with 10-fold cross-validation.

# %% [markdown]
# ## 1. Setup & Imports

# %%
import sys
sys.path.append('..')

from src.data_loader import load_processed_data
from src.evaluation import perform_kfold_cv, calculate_metrics, save_results_json, create_results_dict
import time
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

from catboost import CatBoostRegressor

# %% [markdown]
# ## 2. Load Preprocessed Data

# %%
print("Loading preprocessed data...")
X_train, X_test, y_train, y_test = load_processed_data()
print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
# Out:
# Loading preprocessed data...
# ✓ Loaded processed data from data/processed/
#   Train: (6766, 5), Test: (1692, 5)
# Train set: (6766, 5), Test set: (1692, 5)

# %% [markdown]
# ## 4. Model Configuration

# %%
model = CatBoostRegressor(iterations=100, learning_rate=0.1, depth=6, random_state=42, verbose=False)
print(f"Model: {model}")
# Out:
# Model: <catboost.core.CatBoostRegressor object at 0x7f2f18445940>

# %% [markdown]
# ## 5. Training

# %%
print("Training model...")
start_time = time.time()
model.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"✓ Training completed in {training_time:.4f}s")
# Out:
# Training model...
# ✓ Training completed in 0.2125s

# %% [markdown]
# ## 6. 10-Fold Cross-Validation

# %%
print("Performing 10-fold cross-validation...")
cv_results = perform_kfold_cv(model, X_train, y_train, k=10)
print(f"\nCV RMSE: {cv_results['rmse_mean']:.2f} ± {cv_results['rmse_std']:.2f}")
print(f"CV R²: {cv_results['r2_mean']:.4f} ± {cv_results['r2_std']:.4f}")
# Out:
# Performing 10-fold cross-validation...
# Performing 10-fold cross-validation...
#   Fold 1/10: RMSE=714.97, R²=0.9640
#   Fold 2/10: RMSE=555.36, R²=0.9787
#   Fold 3/10: RMSE=589.89, R²=0.9720
#   Fold 4/10: RMSE=563.38, R²=0.9666
#   Fold 5/10: RMSE=524.43, R²=0.9853
#   Fold 6/10: RMSE=453.02, R²=0.8667
#   Fold 7/10: RMSE=555.62, R²=0.9531
#   Fold 8/10: RMSE=488.93, R²=0.9677
#   Fold 9/10: RMSE=650.62, R²=0.9576
#   Fold 10/10: RMSE=624.95, R²=0.9355
#
#   CV Results:
#     RMSE: 572.12 ± 73.27
#     R²:   0.9547 ± 0.0321
#
# CV RMSE: 572.12 ± 73.27
# CV R²: 0.9547 ± 0.0321

# %% [markdown]
# ## 7. Test Set Evaluation

# %%
print("Evaluating on test set...")
y_pred = model.predict(X_test)
test_rmse, test_r2 = calculate_metrics(y_test, y_pred)
print(f"Test RMSE: {test_rmse:.2f}")
print(f"Test R²: {test_r2:.4f}")
# Out:
# Evaluating on test set...
# Test RMSE: 526.38
# Test R²: 0.9534

# %% [markdown]
# ## 8. Save Results to JSON

# %%
results = create_results_dict(
    algorithm="CatBoost Regression",
    model=model,
    X_train=X_train,
    cv_results=cv_results,
    test_scores={'rmse': float(test_rmse), 'r2': float(test_r2)},
    training_time=training_time
)

save_results_json(results, "09_catboost.json")
print("✓ Results saved to ../results/09_catboost.json")
# Out:
# ✓ Results saved to results/09_catboost.json
# ✓ Results saved to ../results/09_catboost.json

# %% [markdown]
# ## 9. Visualization

# %%
# Actual vs Predicted
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Scatter plot
axes[0].scatter(y_test, y_pred, alpha=0.5)
axes[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0].set_xlabel('Actual')
axes[0].set_ylabel('Predicted')
axes[0].set_title('CatBoost Regression: Actual vs Predicted')
axes[0].grid(True, alpha=0.3)

# Residuals
residuals = y_test - y_pred
axes[1].scatter(y_pred, residuals, alpha=0.5)
axes[1].axhline(y=0, color='r', linestyle='--', lw=2)
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Residuals')
axes[1].set_title('Residual Plot')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
print("\n" + "="*60)
print("CATBOOST MODEL COMPLETE!")
print("="*60)
print(f"CV RMSE: {cv_results['rmse_mean']:.2f} ± {cv_results['rmse_std']:.2f}")
print(f"CV R²: {cv_results['r2_mean']:.4f} ± {cv_results['r2_std']:.4f}")
print(f"Test RMSE: {test_rmse:.2f}")
print(f"Test R²: {test_r2:.4f}")
print("="*60)
# Out:
# ============================================================
# CATBOOST MODEL COMPLETE!
# ============================================================
# CV RMSE: 572.12 ± 73.27
# CV R²: 0.9547 ± 0.0321
# Test RMSE: 526.38
# Test R²: 0.9534
# ============================================================
