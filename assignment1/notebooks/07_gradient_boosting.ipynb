# %% [markdown]
# # Gradient Boosting Regression Model
#
# This notebook trains and evaluates a Gradient Boosting Regression model with 10-fold cross-validation.

# %% [markdown]
# ## 1. Setup & Imports

# %%
import sys
sys.path.append('..')

from src.data_loader import load_processed_data
from src.evaluation import perform_kfold_cv, calculate_metrics, save_results_json, create_results_dict
import time
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# ## 2. Load Preprocessed Data

# %%
print("Loading preprocessed data...")
X_train, X_test, y_train, y_test = load_processed_data()
print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
# Out:
# Loading preprocessed data...
# ✓ Loaded processed data from data/processed/
#   Train: (6766, 5), Test: (1692, 5)
# Train set: (6766, 5), Test set: (1692, 5)

# %% [markdown]
# ## 4. Model Configuration

# %%
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
print(f"Model: {model}")
# Out:
# Model: GradientBoostingRegressor(random_state=42)

# %% [markdown]
# ## 5. Training

# %%
print("Training model...")
start_time = time.time()
model.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"✓ Training completed in {training_time:.4f}s")
# Out:
# Training model...
# ✓ Training completed in 0.2002s

# %% [markdown]
# ## 6. 10-Fold Cross-Validation

# %%
print("Performing 10-fold cross-validation...")
cv_results = perform_kfold_cv(model, X_train, y_train, k=10)
print(f"\nCV RMSE: {cv_results['rmse_mean']:.2f} ± {cv_results['rmse_std']:.2f}")
print(f"CV R²: {cv_results['r2_mean']:.4f} ± {cv_results['r2_std']:.4f}")
# Out:
# Performing 10-fold cross-validation...
# Performing 10-fold cross-validation...
#   Fold 1/10: RMSE=1046.43, R²=0.9229
#   Fold 2/10: RMSE=691.96, R²=0.9669
#   Fold 3/10: RMSE=1048.78, R²=0.9116
#   Fold 4/10: RMSE=786.06, R²=0.9351
#   Fold 5/10: RMSE=990.87, R²=0.9476
#   Fold 6/10: RMSE=502.66, R²=0.8359
#   Fold 7/10: RMSE=821.67, R²=0.8974
#   Fold 8/10: RMSE=773.70, R²=0.9191
#   Fold 9/10: RMSE=852.27, R²=0.9273
#   Fold 10/10: RMSE=801.68, R²=0.8938
#
#   CV Results:
#     RMSE: 831.61 ± 159.13
#     R²:   0.9158 ± 0.0338
#
# CV RMSE: 831.61 ± 159.13
# CV R²: 0.9158 ± 0.0338

# %% [markdown]
# ## 7. Test Set Evaluation

# %%
print("Evaluating on test set...")
y_pred = model.predict(X_test)
test_rmse, test_r2 = calculate_metrics(y_test, y_pred)
print(f"Test RMSE: {test_rmse:.2f}")
print(f"Test R²: {test_r2:.4f}")
# Out:
# Evaluating on test set...
# Test RMSE: 632.15
# Test R²: 0.9328

# %% [markdown]
# ## 8. Save Results to JSON

# %%
results = create_results_dict(
    algorithm="Gradient Boosting Regression",
    model=model,
    X_train=X_train,
    cv_results=cv_results,
    test_scores={'rmse': float(test_rmse), 'r2': float(test_r2)},
    training_time=training_time
)

save_results_json(results, "07_gradient_boosting.json")
print("✓ Results saved to ../results/07_gradient_boosting.json")
# Out:
# ✓ Results saved to results/07_gradient_boosting.json
# ✓ Results saved to ../results/07_gradient_boosting.json

# %% [markdown]
# ## 9. Visualization

# %%
# Actual vs Predicted
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Scatter plot
axes[0].scatter(y_test, y_pred, alpha=0.5)
axes[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
axes[0].set_xlabel('Actual')
axes[0].set_ylabel('Predicted')
axes[0].set_title('Gradient Boosting Regression: Actual vs Predicted')
axes[0].grid(True, alpha=0.3)

# Residuals
residuals = y_test - y_pred
axes[1].scatter(y_pred, residuals, alpha=0.5)
axes[1].axhline(y=0, color='r', linestyle='--', lw=2)
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Residuals')
axes[1].set_title('Residual Plot')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
print("\n" + "="*60)
print("GRADIENT BOOSTING MODEL COMPLETE!")
print("="*60)
print(f"CV RMSE: {cv_results['rmse_mean']:.2f} ± {cv_results['rmse_std']:.2f}")
print(f"CV R²: {cv_results['r2_mean']:.4f} ± {cv_results['r2_std']:.4f}")
print(f"Test RMSE: {test_rmse:.2f}")
print(f"Test R²: {test_r2:.4f}")
print("="*60)
# Out:
# ============================================================
# GRADIENT BOOSTING MODEL COMPLETE!
# ============================================================
# CV RMSE: 831.61 ± 159.13
# CV R²: 0.9158 ± 0.0338
# Test RMSE: 632.15
# Test R²: 0.9328
# ============================================================
